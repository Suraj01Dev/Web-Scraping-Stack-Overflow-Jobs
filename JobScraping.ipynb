# %% [markdown]
# # Web Scraping Best Hiring Companies for Developers from StackOverflow

# %% [markdown]
# The  [**StackOverflow**](https://stackoverflow.com/) is a great website for programmers and developers. It has a great community of people helping other people figure out problems and errors in their code. Not only code, but also any query related to tech can be easily  found in stackoverflow and can be clarified. Stackoverflow also has a job portal page where various tech jobs for developers with various tech stacks can be found.
#
# This notebook revolves around scraping this [**job's listed page**](https://stackoverflow.com/jobs/companies) and fetching vital information about jobs listed on stackoverflow. This project is aimed to make life easier for people who are in need of **jobs based on a particular tech stack**

# %% [markdown]
# ## Web Scraping the Page with detailed explanation
#
# ### [Web Scraping](https://www.geeksforgeeks.org/what-is-web-scraping-and-how-to-use-it/)
# Web scraping is an automated process of getting data from webpages. The data obtained from the webpages are usually in raw form and unstructured. The data obtained is then processed and important information is derived from the data.
#
# Thus fetching and parsing data are the two important basic steps involved webscraping.
#
# **Fetching**
#
# For fetching data in python `Requests` library is used.
#
# **Parsing**
#
# For parsing the raw data `Beautiful soup` library is used.

# %% [markdown]
# ### **The various information collected for each company are as follows:**
#
#   - **Followers**
#
#     Total number of followers
#
#   - **Status**
#
#     Status of the company like how it is funded
#
#   - **Industry**
#
#     The type of industry(Eg: ecommerce, fintech etc)
#
#   - **Founded**
#
#     The year it was founded
#
#   - **Size**
#
#     Total number of employees working
#
#   - **Website**
#
#     Official link of the company
#
#   - **Office Location**
#
#     Location of office
#
#
#   - **Tech stack 1**
#
#     Top 1 tech stack mentioned
#
#   - **Tech stack 2**
#
#     Top 2 tech stack mentioned
#
#   - **Github link**
#
#     Link for github if provided
#
#   - **Twitter link**
#
#     Link for twitter if provided
#
#   - **Location Link**
#
#     Geolocation of the company

# %% [markdown]
# ### Installing required libraries

# %%
# !pip install requests bs4 pandas --quiet

# %% [markdown]
# ### Importing required libraries

# %%
import requests
from bs4 import BeautifulSoup as bs
import json
import pandas as pd

# %% [markdown]
# ### Required links to parse
# This is a dictionary of links which conatins the main stack overflow url and relative link of the job's listed page.

# %%
links={
    "baseUrl":"https://stackoverflow.com",
    "subUrl":"/jobs/companies"
    }

# %% [markdown]
# ### Functions for parsing and scraping data

# %% [markdown]
# ### Parsing the main page
#
# This method is developed to parse the main page of the stackoverflow's job's listing page.
#  It grabs the name of the company and the link to the details regarding the company and stores it in a dictionary, with name of the campany as the key and url of the company as the url.
#
# ```
# maininfo['company name']='company_url.com'
# ```

# %%
def mainParser(pageNo):

    try:
        mainInfo={}
        mainUrl=links['baseUrl']+links['subUrl']+"?pg="+str(pageNo)

        response=requests.get(mainUrl)
        mainPage=bs(response.text,"html.parser")
        mainAtags=mainPage.find_all('a',class_="s-link")
        for tag in mainAtags:
            title=tag.text
            link=tag["href"]
            if title!='\n\n':
                mainInfo[title]=links["baseUrl"]+link
        return mainInfo

    except Exception as e:
        print(str(e))

# %% [markdown]
# ### Parsing a particular company page
#
# Both the functions *aboutParser()*  and *extraParser()* is developed to grab information about the particular jobs page. The functions take the *link * of the page as arguement to scrape the details

# %% [markdown]
# #### Parsing About Information
#
# This function is used to grab the following information
#   - Website link
#   - Size of the company
#   - Status of the company
#   - The type of industry
#   - Number of followers
#   - Twitter Link
#   - Github Link

# %%
def aboutParser(link):
    global page
    response=requests.get(link)
    page=bs(response.text,'html.parser')
    divTag=page.find_all('div',class_="ba bc-black-100 ps-relative p16 bar-sm")
    pTags=divTag[0].find_all('p',class_="fw-bold fs-caption fs-category fc-black-400 mb0")

    wflag=False
    Iflag=False
    Sflag=False
    fflag=False
    sflag=False
    Fflag=False
    



    for tag in pTags:

        if tag.text=="Website":
            attributes["website"].append(tag.parent()[1].find_all('a')[0]["href"])
            wflag=True
        if tag.text=="Industry":
            attributes["industry"].append(tag.parent()[1].text.strip())
            Iflag=True
        if tag.text=="Size":
            attributes["size"].append(tag.parent()[1].text.strip())
            Sflag=True
        if tag.text=="Founded":
            attributes["founded"].append(tag.parent()[1].text.strip())
            fflag=True

        if tag.text=="Status":
            attributes["status"].append(tag.parent()[1].text.strip())
            sflag=True
        if tag.text=="Followers":
            attributes["followers"].append(tag.parent()[1].text.strip())
            Fflag=True


    if not wflag:
            attributes["website"].append(None)
    if not Iflag:
            attributes["industry"].append(None)
    if not Sflag:
            attributes["size"].append(None)
    if not fflag:
            attributes["founded"].append(None)
    if not sflag:
            attributes["status"].append(None)
    if not Fflag:
            attributes["followers"].append(None)
            

    socialTags=divTag[0].find_all('div',class_="flex--item")[-1]
    socialTag=socialTags.find_all('a',class_="js-gps-track")
    tw_flag=False
    gh_flag=False

    for tag in socialTag:
        if "twitter" in tag["href"]:
            attributes["twitterlink"].append(tag["href"])
            tw_flag=True
        
        if "github.com" in tag["href"]:
            attributes["githublink"].append(tag["href"])
            gh_flag=True

    if not tw_flag:
            attributes["twitterlink"].append(None)

    if not gh_flag:
            attributes["githublink"].append(None)

# %% [markdown]
# #### Parsing additional information
#
# This function grabs some additional information such as :
#   - Location Link
#   - Office Locations
#   - **Tech Stack 1**
#   - **Tech Stack 2**

# %%
def extraParser(link):

    divTag=page.find('p',class_="fc-light lh-md fs-body3 sticky:fade-out mb12 sm:mb0")
    attributes["moto"].append(divTag.text.strip())

    locationDivTag=page.find('div',class_="mt32 js-locations")
    if locationDivTag:
        llink=locationDivTag.find('a')["href"]
        if llink:
            attributes["locationLink"].append(llink)
        else:
            attributes["locationLink"].append(None)

        lname=locationDivTag.find('a')["data-query"]
        if lname:
            attributes["officelocations"].append(lname)
        else:
            attributes["officelocations"].append(None)
    else:
        attributes["locationLink"].append(None)
        attributes["officelocations"].append(None)



    tech_stack=page.find('div',class_="fs-body2 mt32 js-nav-content")
    stack_a_tags=tech_stack.find_all('a',class_="flex--item s-tag no-tag-menu")
    tstack1,tstack2=stack_a_tags[:2]

    
    attributes["tstack1"].append(tstack1.text)
    attributes["tstack2"].append(tstack2.text)

# %% [markdown]
# ### Wrapper function
# This function is used as a wrapper function, its called after the main pages are parsed across all pages.

# %%
def subParser(fulldata):
    for data in fulldata:
        link=fulldata[data]
        aboutParser(link)
        extraParser(link)

# %% [markdown]
# ### Main Function
#
#
# The main function is the starting point, where all the functions are called and the data is gathered systematically.

# %%
mainInfos={}
attributes={
        "followers":[],
        "status":[],
        "industry":[],
        "founded":[],
        "size":[],
        "website":[],
        "officelocations":[],
        "moto":[],
        "tstack1":[],
        "tstack2":[],
        "githublink":[],
        "twitterlink":[],
        "locationLink":[]    
    }

if __name__ =="__main__":

    # this varible can be changed to grab more data, the default value is 5 pages
    no_of_pages=5
    for pageNo in range(1,no_of_pages):
        mainInfo=mainParser(pageNo)
        #mainInfo.pop('We do not currently allow content pasted from ChatGPT on Stack Overflow; read our policy here.')
        mainInfos.update(mainInfo)

    attributes["Company Name"]=list(mainInfos.keys())
    subParser(mainInfos)
    df=pd.DataFrame(attributes)
df
# Out:
#    followers     status                                           industry  \
# 0         36    Private     Cloud Services, Security, Software Development
# 1         58     Public  Banking, Financial Technology, Software Develo...
# 2         24    Private  Cybersecurity, Network Security, Software Deve...
# 3         76     Public                             Information Technology
# 4        304    Private                               Financial Technology
# 5        461    Private                   Advertising, Enterprise Software
# 6         73     Public            Computer Software, Financial Technology
# 7        493     Public                                 Financial Services
# 8        143     Public            Biotechnology, Pharmaceuticals, Science
# 9        197     Public                 Software Development / Engineering
# 10        52    Private                                  Computer Software
# 11        40    Private                    Mobile Application, Mobile Game
# 12       110    Private  Industrial Automation, Software Development / ...
# 13       161     Public  Hardware Development, Semiconductors, Software...
# 14       335     Public                         Education Technology, SaaS
# 15        65    Private  Artificial Intelligence, Software Consulting, ...
# 16        19    Private  Agile Software Development, Software Developme...
# 17       627  VC Funded   Agile Software Development, Automotive, Mobility
# 18       101     Public                     Manufacturing, Pharmaceuticals
# 19        24     Public  Information Technology, Technical Services, Tr...
# 20        96     Public  Big Data, Enterprise Software, Information Tec...
# 21       180     Public  Cybersecurity, Federal Agencies, Signals Analysis
# 22        57    Private  Finance, Financial Services, Financial Technology
# 23      1.1k     Public   Android, Cloud Services, Internet Infrastructure
# 24       375    Private  E-Commerce, Information Technology, Logistics ...
# 25       217    Private  Agile Software Development, Cloud Services, Pr...
# 26        70    Private  Ad Tech, Advertising Technology, Mobile Applic...
# 27        17    Private                              Healthcare, Insurance
# 28        52    Private                                     Transportation
# 29        63     Public  Cloud-Based Solutions, Information Technology,...
# 30       104     Public  Computer Software, Databases, Enterprise Software
# 31        34    Private         E-Commerce, Information Technology, Retail
# 32        47     Public         B2B Trade, Online Travel, Travel & Tourism
# 33        85     Public  Broadcast, Digital Media, Digital Video Distri...
# 34       210     Public  Automotive, Software Development / Engineering...
# 35       114    Private  Computer Software, Enterprise Software, Softwa...
# 36        35     Public  Banking, Financial Services, Financial Technology
# 37        19     Public                        Banking, Financial Services
# 38       132     Public                      eCommerce, Internet Marketing
# 39       224     Public  Internet of Things, Manufacturing, Software De...
#
#    founded               size  \
# 0     2017    11-50 employees
# 1     1976   5k-10k employees
# 2     2012    1k-5k employees
# 3     2000     10k+ employees
# 4     2018    1k-5k employees
# 5     2008   501-1k employees
# 6     1983     10k+ employees
# 7     1799     10k+ employees
# 8     1956     10k+ employees
# 9     1907     10k+ employees
# 10    2006  201-500 employees
# 11    2006    11-50 employees
# 12    2003  201-500 employees
# 13    1984     10k+ employees
# 14    2010    1k-5k employees
# 15    None   501-1k employees
# 16    1989   501-1k employees
# 17    2019  201-500 employees
# 18    1923     10k+ employees
# 19    2012   5k-10k employees
# 20    None  201-500 employees
# 21    1952     10k+ employees
# 22    1850     10k+ employees
# 23    1998     10k+ employees
# 24    2015   5k-10k employees
# 25    2011  201-500 employees
# 26    2018    11-50 employees
# 27    1947     10k+ employees
# 28    1927     10k+ employees
# 29    2019   51-200 employees
# 30    2007    1k-5k employees
# 31    1881   5k-10k employees
# 32    2013    1k-5k employees
# 33    None     10k+ employees
# 34    1903     10k+ employees
# 35    1998   501-1k employees
# 36    1985     10k+ employees
# 37    1986     10k+ employees
# 38    1995     10k+ employees
# 39    None     10k+ employees
#
#                                               website  \
# 0                               https://www.ockam.io/
# 1                          https://www.jackhenry.com/
# 2                    https://nordsecurity.com/careers
# 3                                   http://endava.com
# 4               https://about.paypay.ne.jp/career/en/
# 5         https://stackoverflow.com/company/work-here
# 6   https://www.intuit.com/?cid=cpg_so_click_us_ca...
# 7   https://careers.jpmorgan.com/us/en/our-busines...
# 8   https://jobs.thermofisher.com/global/en/c/it-j...
# 9   https://careers.bakerhughes.com/global/en/digi...
# 10                          https://www.gsoft.com/en/
# 11                         https://lotum.com/jobs/dev
# 12                   https://inductiveautomation.com/
# 13  https://www.asml.com/en/careers/job-categories...
# 14                   https://about.udemy.com/careers/
# 15              https://www.cloudflight.io/en/career/
# 16             https://www.maibornwolff.de/en/career/
# 17  https://www.finn.auto/?utm_source=stackoverflo...
# 18                       https://www.novonordisk.com/
# 19                                http://grab.careers
# 20                           https://www.vertica.com/
# 21             http://www.IntelligenceCareers.gov/NSA
# 22  https://www.americanexpress.com/en-us/careers/...
# 23                            https://goo.gle/3DdfDhU
# 24                        https://picnic.app/careers/
# 25                            https://moduscreate.com
# 26                                http://www.adjoe.io
# 27                        https://careers.bupa.co.uk/
# 28                        https://www.volvogroup.com/
# 29                               https://www.atma.io/
# 30                           https://www.mongodb.com/
# 31         http://www.e-breuninger.de/de/karriere/it/
# 32                       https://webbeds.jobsoid.com/
# 33                                   https://wbd.com/
# 34               https://corporate.ford.com/home.html
# 35                 https://www.authoritypartners.com/
# 36                         https://jobs.discover.com/
# 37                          https://www.discover.com/
# 38  https://jobs.ebayinc.com/us/en/c/engineering-jobs
# 39                         http://www.caterpillar.com
#
#                                       officelocations  \
# 0                                                None
# 1               663 West Highway 60\nMonett, MO 65708
# 2                                  Vilnius, Lithuania
# 3                                      United Kingdom
# 4                       Work from anywhere at anytime
# 5     110 William Street\n28th Fl\nNew York, NY 10038
# 6             2701 Coast Ave, Mountain View, CA 94043
# 7                                        Brooklyn, NY
# 8                                        Carlsbad, CA
# 9                                         Houston, TX
# 10  1751 Rue Richardson #1050, Montreal, Quebec H3...
# 11                  Am Goldstein 1, 61231 Bad Nauheim
# 12                   90 Blue Ravine, Folsom CA, 95630
# 13  ASML Veldhoven | De Run 6501,\n5504 DR, Veldho...
# 14                                  San Francisco, CA
# 15     Herengracht 440\n1017BZ Amsterdam\nNetherlands
# 16                    Annastraße 8-10, 86150 Augsburg
# 17                 Prinzregentenplatz 9, 81675 Munich
# 18                 Greater Copenhagen Region, Denmark
# 19                       3 Media Cl, Singapore 138498
# 20  150 Cambridgepark Drive\n10th Floor\nCambridge...
# 21                                     Fort Meade, MD
# 22                                       New York, NY
# 23                                               None
# 24       Van Marwijk Kooystraat 15, 1114AG, Amsterdam
# 25  12100 Sunset Hills Road\nSuite 150\nReston, Vi...
# 26           An der Alster 42, 20099 Hamburg, Germany
# 27                          Salford Quays, Manchester
# 28                                 Gothenburg, SWEDEN
# 29             Wickenburggasse 32, 8010 Graz, Austria
# 30  1633 Broadway, 38th Floor, New York, NY 10019,...
# 31                   Marktstraße 1-3, 70173 Stuttgart
# 32                                      Iasi, Romania
# 33         230 Park Avenue South,\nNew York, NY 10003
# 34                  1 American Rd, Dearborn, MI 48126
# 35  AP Headquarters: 200 Spectrum Center Dr., Suit...
# 36            2500 Lake Cook Rd, Riverwoods, IL 60015
# 37  Ascent 3, 2 Lakeside Road, Farnborough GU14 6X...
# 38  2025 Hamilton Ave\nSan Jose, California 95125 USA
# 39                                         Chicago IL
#
#                                                  moto      tstack1  \
# 0     Trust for Data-in-Motion.\r\n\r\nWe are Hiring!         rust
# 1   Jack Henry is a well-rounded financial technol...        scala
# 2                       Creating a safe cyber future.          php
# 3   Reimagining the relationship between people an...      reactjs
# 4   Work for Life or Work for Rice  /We are Japan ...         java
# 5   Stack Overflow empowers the world to develop t...           c#
# 6   Intuit’s Engineering and Data teams are using ...         java
# 7                   www.jpmorganchase.com/techcareers         java
# 8   Our Mission is to enable our customers to make...   javascript
# 9   We take energy forward - making it safer, clea...         .net
# 10  We’re GSoft, home to a family of software prod...   typescript
# 11                            Small Team - Big Impact   javascript
# 12  To create industrial software that empowers ou...         java
# 13  Software makes our machines perform beyond raw...           c#
# 14  We improve lives through learning by empowerin...       python
# 15  We make a digital difference by delivering cus...       kotlin
# 16                          people. code. commitment.       mobile
# 17  FINN is your monthly car subscription with eve...      reactjs
# 18  Join us at the forefront of digital healthcare...   javascript
# 19  Grab is Southeast Asia’s leading superapp, pro...       golang
# 20  Unified Analytics powering the fastest analyti...            c
# 21                   Where Intelligence Goes to Work®         java
# 22  Architect, code and ship software that makes u...         java
# 23  Our mission is to organize the world’s informa...         java
# 24  We’re revolutionizing the way people buy groce...         java
# 25  Modus Create is a digital consulting firm dedi...   javascript
# 26    We Build Advertising Technologies to Outperform          ios
# 27  Helping people live longer, healthier, happier...        azure
# 28  Driving prosperity through transport and infra...      reactjs
# 29  atma.io -->the world's leading connected produ...         .net
# 30  MongoDB empowers innovators to create, transfo...          c++
# 31  Dies sind die Team Breuninger Developer Advent...         java
# 32  WebBeds is the fastest growing & most signific...          php
# 33  Warner Bros. Discovery is a premier entertainm...         java
# 34  We are here for one purpose, to help build a b...       python
# 35  Authority Partners is the premier IT solutions...           c#
# 36                    Bring Ingenuity, Shine Bright®.  tableau-api
# 37               Leading the way to a brighter future   javascript
# 38  We connect people and build communities to cre...   javascript
# 39  Cat Digital uses digital technologies to help ...         java
#
#             tstack2                                 githublink  \
# 0            elixir       https://github.com/build-trust/ockam
# 1                go                   https://github.com/Banno
# 2                go            https://github.com/NordSecurity
# 3           angular                                       None
# 4       spring-boot                                       None
# 5       asp.net-mvc           https://github.com/stackexchange
# 6            kotlin                  https://github.com/intuit
# 7            python                                       None
# 8               sql                                       None
# 9      corestandard                                       None
# 10      react-hooks               https://github.com/gsoft-inc
# 11       typescript                                       None
# 12           python                                       None
# 13          java-ee                                       None
# 14           hadoop                   https://github.com/Udemy
# 15             java           https://github.com/cloudflightio
# 16          testing            https://github.com/MaibornWolff
# 17             yarn                                       None
# 18             html                                       None
# 19       javascript                                       None
# 20             java                                       None
# 21                c  https://github.com/nationalsecurityagency
# 22           python                                       None
# 23       javascript                                       None
# 24           python       https://github.com/PicnicSupermarket
# 25          reactjs             https://github.com/moduscreate
# 26          android                 https://github.com/adjoeio
# 27               c#                                       None
# 28            redux                                       None
# 29     asp.net-core                                       None
# 30            c++17           https://github.com/mongodb/mongo
# 31            scala                                       None
# 32             .net                                       None
# 33      spring-boot                                       None
# 34  user-experience                                       None
# 35             .net                                       None
# 36          powerbi                                       None
# 37      tableau-api                                       None
# 38          node.js                    https://github.com/eBay
# 39       javascript                                       None
#
#                             twitterlink  \
# 0             https://twitter.com/ockam
# 1        https://twitter.com/JH_Fintech
# 2      https://twitter.com/NordNewsroom
# 3            https://twitter.com/endava
# 4    https://twitter.com/PayPayOfficial
# 5     https://twitter.com/stackoverflow
# 6            https://twitter.com/intuit
# 7                                  None
# 8    https://twitter.com/MyThermoFisher
# 9     https://twitter.com/bakerhughesco
# 10       https://twitter.com/gsoftgroup
# 11      https://twitter.com/lotum_games
# 12    https://twitter.com/InductiveAuto
# 13      https://twitter.com/ASMLcompany
# 14            https://twitter.com/Udemy
# 15    https://twitter.com/cloudflightio
# 16     https://twitter.com/MaibornWolff
# 17                                 None
# 18      https://twitter.com/novonordisk
# 19                                 None
# 20   https://twitter.com/VerticaUnified
# 21           https://twitter.com/NSAGov
# 22  https://twitter.com/AmericanExpress
# 23     https://twitter.com/lifeatgoogle
# 24           https://twitter.com/picnic
# 25      https://twitter.com/moduscreate
# 26                                 None
# 27    https://twitter.com/BupaUKCareers
# 28       https://twitter.com/volvogroup
# 29       https://twitter.com/ADSmartrac
# 30          https://twitter.com/MongoDB
# 31   https://twitter.com/teambreuninger
# 32                                 None
# 33              https://twitter.com/wbd
# 34      https://twitter.com/FordCareers
# 35       https://twitter.com/apiknowsit
# 36         https://twitter.com/discover
# 37         https://twitter.com/discover
# 38         https://twitter.com/ebaytech
# 39   https://twitter.com/caterpillarinc
#
#                                          locationLink  \
# 0                                                None
# 1   https://www.google.com/maps/search/?api=1&quer...
# 2   https://www.google.com/maps/search/?api=1&quer...
# 3   https://www.google.com/maps/search/?api=1&quer...
# 4   https://www.google.com/maps/search/?api=1&quer...
# 5   https://www.google.com/maps/search/?api=1&quer...
# 6   https://www.google.com/maps/search/?api=1&quer...
# 7   https://www.google.com/maps/search/?api=1&quer...
# 8   https://www.google.com/maps/search/?api=1&quer...
# 9   https://www.google.com/maps/search/?api=1&quer...
# 10  https://www.google.com/maps/search/?api=1&quer...
# 11  https://www.google.com/maps/search/?api=1&quer...
# 12  https://www.google.com/maps/search/?api=1&quer...
# 13  https://www.google.com/maps/search/?api=1&quer...
# 14  https://www.google.com/maps/search/?api=1&quer...
# 15  https://www.google.com/maps/search/?api=1&quer...
# 16  https://www.google.com/maps/search/?api=1&quer...
# 17  https://www.google.com/maps/search/?api=1&quer...
# 18  https://www.google.com/maps/search/?api=1&quer...
# 19  https://www.google.com/maps/search/?api=1&quer...
# 20  https://www.google.com/maps/search/?api=1&quer...
# 21  https://www.google.com/maps/search/?api=1&quer...
# 22  https://www.google.com/maps/search/?api=1&quer...
# 23                                               None
# 24  https://www.google.com/maps/search/?api=1&quer...
# 25  https://www.google.com/maps/search/?api=1&quer...
# 26  https://www.google.com/maps/search/?api=1&quer...
# 27  https://www.google.com/maps/search/?api=1&quer...
# 28  https://www.google.com/maps/search/?api=1&quer...
# 29  https://www.google.com/maps/search/?api=1&quer...
# 30  https://www.google.com/maps/search/?api=1&quer...
# 31  https://www.google.com/maps/search/?api=1&quer...
# 32  https://www.google.com/maps/search/?api=1&quer...
# 33  https://www.google.com/maps/search/?api=1&quer...
# 34  https://www.google.com/maps/search/?api=1&quer...
# 35  https://www.google.com/maps/search/?api=1&quer...
# 36  https://www.google.com/maps/search/?api=1&quer...
# 37  https://www.google.com/maps/search/?api=1&quer...
# 38  https://www.google.com/maps/search/?api=1&quer...
# 39  https://www.google.com/maps/search/?api=1&quer...
#
#                         Company Name
# 0                              Ockam
# 1     Jack Henry & Associates, Inc.®
# 2                      Nord Security
# 3                            Endava
# 4                PayPay Corporation.
# 5                     Stack Overflow
# 6                             Intuit
# 7               JPMorgan Chase & Co.
# 8   Thermo Fisher Scientific Careers
# 9                       Baker Hughes
# 10                             GSoft
# 11                        Lotum GmbH
# 12             Inductive Automation
# 13                              ASML
# 14                             Udemy
# 15                       Cloudflight
# 16                 MaibornWolff GmbH
# 17                              FINN
# 18                  Novo Nordisk A/S
# 19                              Grab
# 20                           Vertica
# 21          National Security Agency
# 22                 American Express.
# 23                            Google
# 24                            Picnic
# 25                      Modus Create
# 26                            adjoe
# 27                              Bupa
# 28                       Volvo Group
# 29                          atma.io
# 30                           MongoDB
# 31             Breuninger GmbH & Co.
# 32                      WebBeds Tech
# 33            Warner Bros. Discovery
# 34                Ford Motor Company
# 35                Authority Partners
# 36       Discover Financial Services
# 37           Discover Financial Svcs
# 38                              eBay
# 39                  Caterpillar Inc.

# %% [markdown]
# ## Summary and Conclusion

# %% [markdown]
# Thus the stackoverflow job portal was scraped and parsed to gather various imporatant informations related to jobs which will make life a lot easier for a person looking for a job based on a particular specific **tech stack**. And other useful informations like the website of the company and the number of employees working in a company. These small factors  will guide him/ her to choose the best company that he/she deserves.

# %% [markdown]
# The dataframe can be slightly tweaked and can be looked at it from a different perspective. This will help the user to narrow his job search based on tech stacks that he is proficient in .

# %%
tech=df.groupby(['tstack1','tstack2'])

# %%
tech.first()
# Out:
#                             followers     status  \
# tstack1     tstack2
# .net        asp.net-core           63     Public
#             corestandard          197     Public
# azure       c#                     17    Private
# c           java                   96     Public
# c#          .net                  114    Private
#             asp.net-mvc           461    Private
#             java-ee               161     Public
# c++         c++17                 104     Public
# golang      javascript             24     Public
# ios         android                70    Private
# java        c                     180     Public
#             javascript           1.1k     Public
#             kotlin                 73     Public
#             python                493     Public
#             scala                  34    Private
#             spring-boot           304    Private
# javascript  html                  101     Public
#             node.js               132     Public
#             reactjs               217    Private
#             sql                   143     Public
#             tableau-api            19     Public
#             typescript             40    Private
# kotlin      java                   65    Private
# mobile      testing                19    Private
# php         .net                   47     Public
#             go                     24    Private
# python      hadoop                335     Public
#             user-experience       210     Public
# reactjs     angular                76     Public
#             redux                  52    Private
#             yarn                  627  VC Funded
# rust        elixir                 36    Private
# scala       go                     58     Public
# tableau-api powerbi                35     Public
# typescript  react-hooks            52    Private
#
#                                                                       industry  \
# tstack1     tstack2
# .net        asp.net-core     Cloud-Based Solutions, Information Technology,...
#             corestandard                    Software Development / Engineering
# azure       c#                                           Healthcare, Insurance
# c           java             Big Data, Enterprise Software, Information Tec...
# c#          .net             Computer Software, Enterprise Software, Softwa...
#             asp.net-mvc                       Advertising, Enterprise Software
#             java-ee          Hardware Development, Semiconductors, Software...
# c++         c++17            Computer Software, Databases, Enterprise Software
# golang      javascript       Information Technology, Technical Services, Tr...
# ios         android          Ad Tech, Advertising Technology, Mobile Applic...
# java        c                Cybersecurity, Federal Agencies, Signals Analysis
#             javascript        Android, Cloud Services, Internet Infrastructure
#             kotlin                     Computer Software, Financial Technology
#             python                                          Financial Services
#             scala                   E-Commerce, Information Technology, Retail
#             spring-boot                                   Financial Technology
# javascript  html                                Manufacturing, Pharmaceuticals
#             node.js                              eCommerce, Internet Marketing
#             reactjs          Agile Software Development, Cloud Services, Pr...
#             sql                        Biotechnology, Pharmaceuticals, Science
#             tableau-api                            Banking, Financial Services
#             typescript                         Mobile Application, Mobile Game
# kotlin      java             Artificial Intelligence, Software Consulting, ...
# mobile      testing          Agile Software Development, Software Developme...
# php         .net                    B2B Trade, Online Travel, Travel & Tourism
#             go               Cybersecurity, Network Security, Software Deve...
# python      hadoop                                  Education Technology, SaaS
#             user-experience  Automotive, Software Development / Engineering...
# reactjs     angular                                     Information Technology
#             redux                                               Transportation
#             yarn              Agile Software Development, Automotive, Mobility
# rust        elixir              Cloud Services, Security, Software Development
# scala       go               Banking, Financial Technology, Software Develo...
# tableau-api powerbi          Banking, Financial Services, Financial Technology
# typescript  react-hooks                                      Computer Software
#
#                             founded               size  \
# tstack1     tstack2
# .net        asp.net-core       2019   51-200 employees
#             corestandard       1907     10k+ employees
# azure       c#                 1947     10k+ employees
# c           java               None  201-500 employees
# c#          .net               1998   501-1k employees
#             asp.net-mvc        2008   501-1k employees
#             java-ee            1984     10k+ employees
# c++         c++17              2007    1k-5k employees
# golang      javascript         2012   5k-10k employees
# ios         android            2018    11-50 employees
# java        c                  1952     10k+ employees
#             javascript         1998     10k+ employees
#             kotlin             1983     10k+ employees
#             python             1799     10k+ employees
#             scala              1881   5k-10k employees
#             spring-boot        2018    1k-5k employees
# javascript  html               1923     10k+ employees
#             node.js            1995     10k+ employees
#             reactjs            2011  201-500 employees
#             sql                1956     10k+ employees
#             tableau-api        1986     10k+ employees
#             typescript         2006    11-50 employees
# kotlin      java               None   501-1k employees
# mobile      testing            1989   501-1k employees
# php         .net               2013    1k-5k employees
#             go                 2012    1k-5k employees
# python      hadoop             2010    1k-5k employees
#             user-experience    1903     10k+ employees
# reactjs     angular            2000     10k+ employees
#             redux              1927     10k+ employees
#             yarn               2019  201-500 employees
# rust        elixir             2017    11-50 employees
# scala       go                 1976   5k-10k employees
# tableau-api powerbi            1985     10k+ employees
# typescript  react-hooks        2006  201-500 employees
#
#                                                                        website  \
# tstack1     tstack2
# .net        asp.net-core                                  https://www.atma.io/
#             corestandard     https://careers.bakerhughes.com/global/en/digi...
# azure       c#                                     https://careers.bupa.co.uk/
# c           java                                      https://www.vertica.com/
# c#          .net                            https://www.authoritypartners.com/
#             asp.net-mvc            https://stackoverflow.com/company/work-here
#             java-ee          https://www.asml.com/en/careers/job-categories...
# c++         c++17                                     https://www.mongodb.com/
# golang      javascript                                     http://grab.careers
# ios         android                                        http://www.adjoe.io
# java        c                           http://www.IntelligenceCareers.gov/NSA
#             javascript                                 https://goo.gle/3DdfDhU
#             kotlin           https://www.intuit.com/?cid=cpg_so_click_us_ca...
#             python           https://careers.jpmorgan.com/us/en/our-busines...
#             scala                   http://www.e-breuninger.de/de/karriere/it/
#             spring-boot                  https://about.paypay.ne.jp/career/en/
# javascript  html                                  https://www.novonordisk.com/
#             node.js          https://jobs.ebayinc.com/us/en/c/engineering-jobs
#             reactjs                                    https://moduscreate.com
#             sql              https://jobs.thermofisher.com/global/en/c/it-j...
#             tableau-api                              https://www.discover.com/
#             typescript                              https://lotum.com/jobs/dev
# kotlin      java                         https://www.cloudflight.io/en/career/
# mobile      testing                     https://www.maibornwolff.de/en/career/
# php         .net                                  https://webbeds.jobsoid.com/
#             go                                https://nordsecurity.com/careers
# python      hadoop                            https://about.udemy.com/careers/
#             user-experience               https://corporate.ford.com/home.html
# reactjs     angular                                          http://endava.com
#             redux                                  https://www.volvogroup.com/
#             yarn             https://www.finn.auto/?utm_source=stackoverflo...
# rust        elixir                                       https://www.ockam.io/
# scala       go                                      https://www.jackhenry.com/
# tableau-api powerbi                                 https://jobs.discover.com/
# typescript  react-hooks                              https://www.gsoft.com/en/
#
#                                                                officelocations  \
# tstack1     tstack2
# .net        asp.net-core                Wickenburggasse 32, 8010 Graz, Austria
#             corestandard                                           Houston, TX
# azure       c#                                       Salford Quays, Manchester
# c           java             150 Cambridgepark Drive\n10th Floor\nCambridge...
# c#          .net             AP Headquarters: 200 Spectrum Center Dr., Suit...
#             asp.net-mvc        110 William Street\n28th Fl\nNew York, NY 10038
#             java-ee          ASML Veldhoven | De Run 6501,\n5504 DR, Veldho...
# c++         c++17            1633 Broadway, 38th Floor, New York, NY 10019,...
# golang      javascript                            3 Media Cl, Singapore 138498
# ios         android                   An der Alster 42, 20099 Hamburg, Germany
# java        c                                                   Fort Meade, MD
#             javascript                                              Chicago IL
#             kotlin                     2701 Coast Ave, Mountain View, CA 94043
#             python                                                Brooklyn, NY
#             scala                             Marktstraße 1-3, 70173 Stuttgart
#             spring-boot                          Work from anywhere at anytime
# javascript  html                            Greater Copenhagen Region, Denmark
#             node.js          2025 Hamilton Ave\nSan Jose, California 95125 USA
#             reactjs          12100 Sunset Hills Road\nSuite 150\nReston, Vi...
#             sql                                                   Carlsbad, CA
#             tableau-api      Ascent 3, 2 Lakeside Road, Farnborough GU14 6X...
#             typescript                       Am Goldstein 1, 61231 Bad Nauheim
# kotlin      java                Herengracht 440\n1017BZ Amsterdam\nNetherlands
# mobile      testing                            Annastraße 8-10, 86150 Augsburg
# php         .net                                                 Iasi, Romania
#             go                                              Vilnius, Lithuania
# python      hadoop                                           San Francisco, CA
#             user-experience                  1 American Rd, Dearborn, MI 48126
# reactjs     angular                                             United Kingdom
#             redux                                           Gothenburg, SWEDEN
#             yarn                            Prinzregentenplatz 9, 81675 Munich
# rust        elixir                                                        None
# scala       go                           663 West Highway 60\nMonett, MO 65708
# tableau-api powerbi                    2500 Lake Cook Rd, Riverwoods, IL 60015
# typescript  react-hooks      1751 Rue Richardson #1050, Montreal, Quebec H3...
#
#                                                                           moto  \
# tstack1     tstack2
# .net        asp.net-core     atma.io -->the world's leading connected produ...
#             corestandard     We take energy forward - making it safer, clea...
# azure       c#               Helping people live longer, healthier, happier...
# c           java             Unified Analytics powering the fastest analyti...
# c#          .net             Authority Partners is the premier IT solutions...
#             asp.net-mvc      Stack Overflow empowers the world to develop t...
#             java-ee          Software makes our machines perform beyond raw...
# c++         c++17            MongoDB empowers innovators to create, transfo...
# golang      javascript       Grab is Southeast Asia’s leading superapp, pro...
# ios         android            We Build Advertising Technologies to Outperform
# java        c                                 Where Intelligence Goes to Work®
#             javascript       Our mission is to organize the world’s informa...
#             kotlin           Intuit’s Engineering and Data teams are using ...
#             python                           www.jpmorganchase.com/techcareers
#             scala            Dies sind die Team Breuninger Developer Advent...
#             spring-boot      Work for Life or Work for Rice  /We are Japan ...
# javascript  html             Join us at the forefront of digital healthcare...
#             node.js          We connect people and build communities to cre...
#             reactjs          Modus Create is a digital consulting firm dedi...
#             sql              Our Mission is to enable our customers to make...
#             tableau-api                   Leading the way to a brighter future
#             typescript                                 Small Team - Big Impact
# kotlin      java             We make a digital difference by delivering cus...
# mobile      testing                                  people. code. commitment.
# php         .net             WebBeds is the fastest growing & most signific...
#             go                                   Creating a safe cyber future.
# python      hadoop           We improve lives through learning by empowerin...
#             user-experience  We are here for one purpose, to help build a b...
# reactjs     angular          Reimagining the relationship between people an...
#             redux            Driving prosperity through transport and infra...
#             yarn             FINN is your monthly car subscription with eve...
# rust        elixir             Trust for Data-in-Motion.\r\n\r\nWe are Hiring!
# scala       go               Jack Henry is a well-rounded financial technol...
# tableau-api powerbi                            Bring Ingenuity, Shine Bright®.
# typescript  react-hooks      We’re GSoft, home to a family of software prod...
#
#                                                             githublink  \
# tstack1     tstack2
# .net        asp.net-core                                          None
#             corestandard                                          None
# azure       c#                                                    None
# c           java                                                  None
# c#          .net                                                  None
#             asp.net-mvc               https://github.com/stackexchange
#             java-ee                                               None
# c++         c++17                     https://github.com/mongodb/mongo
# golang      javascript                                            None
# ios         android                         https://github.com/adjoeio
# java        c                https://github.com/nationalsecurityagency
#             javascript                                            None
#             kotlin                           https://github.com/intuit
#             python                https://github.com/PicnicSupermarket
#             scala                                                 None
#             spring-boot                                           None
# javascript  html                                                  None
#             node.js                            https://github.com/eBay
#             reactjs                     https://github.com/moduscreate
#             sql                                                   None
#             tableau-api                                           None
#             typescript                                            None
# kotlin      java                      https://github.com/cloudflightio
# mobile      testing                    https://github.com/MaibornWolff
# php         .net                                                  None
#             go                         https://github.com/NordSecurity
# python      hadoop                            https://github.com/Udemy
#             user-experience                                       None
# reactjs     angular                                               None
#             redux                                                 None
#             yarn                                                  None
# rust        elixir                https://github.com/build-trust/ockam
# scala       go                                https://github.com/Banno
# tableau-api powerbi                                               None
# typescript  react-hooks                   https://github.com/gsoft-inc
#
#                                                     twitterlink  \
# tstack1     tstack2
# .net        asp.net-core         https://twitter.com/ADSmartrac
#             corestandard      https://twitter.com/bakerhughesco
# azure       c#                https://twitter.com/BupaUKCareers
# c           java             https://twitter.com/VerticaUnified
# c#          .net                 https://twitter.com/apiknowsit
#             asp.net-mvc       https://twitter.com/stackoverflow
#             java-ee             https://twitter.com/ASMLcompany
# c++         c++17                   https://twitter.com/MongoDB
# golang      javascript                                     None
# ios         android                                        None
# java        c                        https://twitter.com/NSAGov
#             javascript         https://twitter.com/lifeatgoogle
#             kotlin                   https://twitter.com/intuit
#             python            https://twitter.com/InductiveAuto
#             scala            https://twitter.com/teambreuninger
#             spring-boot      https://twitter.com/PayPayOfficial
# javascript  html                https://twitter.com/novonordisk
#             node.js                https://twitter.com/ebaytech
#             reactjs             https://twitter.com/moduscreate
#             sql              https://twitter.com/MyThermoFisher
#             tableau-api            https://twitter.com/discover
#             typescript          https://twitter.com/lotum_games
# kotlin      java              https://twitter.com/cloudflightio
# mobile      testing            https://twitter.com/MaibornWolff
# php         .net                                           None
#             go                 https://twitter.com/NordNewsroom
# python      hadoop                    https://twitter.com/Udemy
#             user-experience     https://twitter.com/FordCareers
# reactjs     angular                  https://twitter.com/endava
#             redux                https://twitter.com/volvogroup
#             yarn                                           None
# rust        elixir                    https://twitter.com/ockam
# scala       go                   https://twitter.com/JH_Fintech
# tableau-api powerbi                https://twitter.com/discover
# typescript  react-hooks          https://twitter.com/gsoftgroup
#
#                                                                   locationLink  \
# tstack1     tstack2
# .net        asp.net-core     https://www.google.com/maps/search/?api=1&quer...
#             corestandard     https://www.google.com/maps/search/?api=1&quer...
# azure       c#               https://www.google.com/maps/search/?api=1&quer...
# c           java             https://www.google.com/maps/search/?api=1&quer...
# c#          .net             https://www.google.com/maps/search/?api=1&quer...
#             asp.net-mvc      https://www.google.com/maps/search/?api=1&quer...
#             java-ee          https://www.google.com/maps/search/?api=1&quer...
# c++         c++17            https://www.google.com/maps/search/?api=1&quer...
# golang      javascript       https://www.google.com/maps/search/?api=1&quer...
# ios         android          https://www.google.com/maps/search/?api=1&quer...
# java        c                https://www.google.com/maps/search/?api=1&quer...
#             javascript       https://www.google.com/maps/search/?api=1&quer...
#             kotlin           https://www.google.com/maps/search/?api=1&quer...
#             python           https://www.google.com/maps/search/?api=1&quer...
#             scala            https://www.google.com/maps/search/?api=1&quer...
#             spring-boot      https://www.google.com/maps/search/?api=1&quer...
# javascript  html             https://www.google.com/maps/search/?api=1&quer...
#             node.js          https://www.google.com/maps/search/?api=1&quer...
#             reactjs          https://www.google.com/maps/search/?api=1&quer...
#             sql              https://www.google.com/maps/search/?api=1&quer...
#             tableau-api      https://www.google.com/maps/search/?api=1&quer...
#             typescript       https://www.google.com/maps/search/?api=1&quer...
# kotlin      java             https://www.google.com/maps/search/?api=1&quer...
# mobile      testing          https://www.google.com/maps/search/?api=1&quer...
# php         .net             https://www.google.com/maps/search/?api=1&quer...
#             go               https://www.google.com/maps/search/?api=1&quer...
# python      hadoop           https://www.google.com/maps/search/?api=1&quer...
#             user-experience  https://www.google.com/maps/search/?api=1&quer...
# reactjs     angular          https://www.google.com/maps/search/?api=1&quer...
#             redux            https://www.google.com/maps/search/?api=1&quer...
#             yarn             https://www.google.com/maps/search/?api=1&quer...
# rust        elixir                                                        None
# scala       go               https://www.google.com/maps/search/?api=1&quer...
# tableau-api powerbi          https://www.google.com/maps/search/?api=1&quer...
# typescript  react-hooks      https://www.google.com/maps/search/?api=1&quer...
#
#                                                  Company Name
# tstack1     tstack2
# .net        asp.net-core                             atma.io
#             corestandard                         Baker Hughes
# azure       c#                                           Bupa
# c           java                                      Vertica
# c#          .net                           Authority Partners
#             asp.net-mvc                        Stack Overflow
#             java-ee                                      ASML
# c++         c++17                                     MongoDB
# golang      javascript                                   Grab
# ios         android                                    adjoe
# java        c                        National Security Agency
#             javascript                                 Google
#             kotlin                                     Intuit
#             python                       JPMorgan Chase & Co.
#             scala                       Breuninger GmbH & Co.
#             spring-boot                   PayPay Corporation.
# javascript  html                             Novo Nordisk A/S
#             node.js                                      eBay
#             reactjs                              Modus Create
#             sql              Thermo Fisher Scientific Careers
#             tableau-api               Discover Financial Svcs
#             typescript                             Lotum GmbH
# kotlin      java                                  Cloudflight
# mobile      testing                         MaibornWolff GmbH
# php         .net                                 WebBeds Tech
#             go                                  Nord Security
# python      hadoop                                      Udemy
#             user-experience                Ford Motor Company
# reactjs     angular                                   Endava
#             redux                                 Volvo Group
#             yarn                                         FINN
# rust        elixir                                      Ockam
# scala       go                 Jack Henry & Associates, Inc.®
# tableau-api powerbi               Discover Financial Services
# typescript  react-hooks                                 GSoft
